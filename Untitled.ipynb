# %%
import numpy as np
import gymnasium as gym
import gymnasium_robotics

from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecTransposeImage
from stable_baselines3.common.monitor import Monitor

gym.register_envs(gymnasium_robotics)

# %%
class PixelObservationWrapper(gym.ObservationWrapper):
    def __init__(self, env, width=84, height=84, camera_id=0):
        super().__init__(env)
        self.width = width
        self.height = height
        self.camera_id = camera_id
        # observation_space now pure image
        self.observation_space = gym.spaces.Box(
            low=0, high=255, shape=(height, width, 3), dtype=np.uint8
        )

    def observation(self, obs):
        frame = self.env.render()
        # some envs render (W,H,3) others (H,W,3)
        return np.array(frame, dtype=np.uint8)

# usage
env = gym.make("FetchReach-v4", render_mode="rgb_array", max_episode_steps=50)
env = PixelObservationWrapper(env, width=84, height=84, camera_id=0)

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.callbacks import CheckpointCallback
import time

# --- 1. Configuration ---

ENV_ID = "FetchReach-v4"  # A simpler Fetch task to start with
N_ENVS = 8                # Use multiple environments for PPO
TOTAL_TIMESTEPS = 2_00_000 # Fetch envs need many steps (e.g., 1M+)
MODEL_PATH = "ppo_fetch_reach"
TENSORBOARD_LOG = "./ppo_fetch_tensorboard/"

# --- 2. Create the Vectorized Environment ---

# make_vec_env handles creating multiple parallel envs
print("Creating environments...")
env = make_vec_env(ENV_ID, n_envs=N_ENVS, seed=0, env_kwargs=dict(reward_type="dense", max_episode_steps=50),)

# IMPORTANT:
# Fetch environments use a `Dict` observation space:
# { 'observation': array, 'achieved_goal': array, 'desired_goal': array }
# Because of this, we MUST use the "MultiInputPolicy".
print(f"Observation space: {env.observation_space}")

# --- 3. Define the Model ---

# We use "MultiInputPolicy" to handle the Dict observation space
print("Initializing PPO model...")
model = PPO(
    "MultiInputPolicy",
    env,
    n_steps=1024,          # Num steps to collect before updating policy
    batch_size=64,         # Minibatch size
    n_epochs=10,           # Num of epochs when updating policy
    gamma=0.99,            # Discount factor
    gae_lambda=0.95,       # Factor for GAE
    learning_rate=3e-4,    # Learning rate
    verbose=1,
    tensorboard_log=TENSORBOARD_LOG
)

# --- 4. Setup Callbacks (Optional but recommended) ---

# Save a checkpoint every 100,000 steps
checkpoint_callback = CheckpointCallback(
    save_freq=max(100_000 // N_ENVS, 1),
    save_path=f"./logs/{MODEL_PATH}/",
    name_prefix="checkpoint",
)

# --- 5. Train the Model ---

print(f"Starting training for {TOTAL_TIMESTEPS} steps...")
start_time = time.time()
model.learn(
    total_timesteps=TOTAL_TIMESTEPS,
    callback=checkpoint_callback,
    progress_bar=True
)
end_time = time.time()
print(f"Training finished in {end_time - start_time:.2f} seconds.")

# --- 6. Save the Final Model ---

model.save(MODEL_PATH)
print(f"Final model saved to {MODEL_PATH}.zip")

# Note: If you use VecNormalize, you must save its stats too
# env.save("vec_normalize_fetch.pkl")

env.close()

# --- 7. Evaluate the Trained Agent ---
# Out:
# Creating environments...
# Observation space: Dict('achieved_goal': Box(-inf, inf, (3,), float64), 'desired_goal': Box(-inf, inf, (3,),
# float64), 'observation': Box(-inf, inf, (10,), float64))
# Initializing PPO model...
# Using cuda device
# Starting training for 200000 steps...
# Logging to ./ppo_fetch_tensorboard/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 50       |
# |    ep_rew_mean     | -10.6    |
# |    success_rate    | 0.01     |
# | time/              |          |
# |    fps             | 344      |
# |    iterations      | 1        |
# |    time_elapsed    | 23       |
# |    total_timesteps | 8192     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -9.98       |
# |    success_rate         | 0.01        |
# | time/                   |             |
# |    fps                  | 296         |
# |    iterations           | 2           |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008296474 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.000976    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.639       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00664    |
# |    std                  | 0.997       |
# |    value_loss           | 1.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -8.35       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 256         |
# |    iterations           | 3           |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010440599 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.66       |
# |    explained_variance   | 0.027       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.617       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0113     |
# |    std                  | 0.995       |
# |    value_loss           | 1.26        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -6.79       |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 243         |
# |    iterations           | 4           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.011548223 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.62       |
# |    explained_variance   | -0.00123    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.319       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.986       |
# |    value_loss           | 0.724       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -5.77       |
# |    success_rate         | 0.12        |
# | time/                   |             |
# |    fps                  | 245         |
# |    iterations           | 5           |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016333347 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.6        |
# |    explained_variance   | 0.0899      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.178       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.981       |
# |    value_loss           | 0.418       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -4.7        |
# |    success_rate         | 0.19        |
# | time/                   |             |
# |    fps                  | 237         |
# |    iterations           | 6           |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.020322803 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.59       |
# |    explained_variance   | 0.146       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0616      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0229     |
# |    std                  | 0.976       |
# |    value_loss           | 0.205       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -3.82       |
# |    success_rate         | 0.16        |
# | time/                   |             |
# |    fps                  | 244         |
# |    iterations           | 7           |
# |    time_elapsed         | 234         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.022468142 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.52       |
# |    explained_variance   | 0.232       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00693     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0224     |
# |    std                  | 0.958       |
# |    value_loss           | 0.0919      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -3.38      |
# |    success_rate         | 0.35       |
# | time/                   |            |
# |    fps                  | 259        |
# |    iterations           | 8          |
# |    time_elapsed         | 252        |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.02336447 |
# |    clip_fraction        | 0.227      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.42      |
# |    explained_variance   | 0.498      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0175     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0222    |
# |    std                  | 0.934      |
# |    value_loss           | 0.0387     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -3.06       |
# |    success_rate         | 0.48        |
# | time/                   |             |
# |    fps                  | 272         |
# |    iterations           | 9           |
# |    time_elapsed         | 270         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.023718093 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.34       |
# |    explained_variance   | 0.535       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0324     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0204     |
# |    std                  | 0.916       |
# |    value_loss           | 0.0321      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50        |
# |    ep_rew_mean          | -2.66     |
# |    success_rate         | 0.61      |
# | time/                   |           |
# |    fps                  | 279       |
# |    iterations           | 10        |
# |    time_elapsed         | 293       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0230328 |
# |    clip_fraction        | 0.246     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.23     |
# |    explained_variance   | 0.586     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0423   |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.017    |
# |    std                  | 0.889     |
# |    value_loss           | 0.0251    |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -2.51       |
# |    success_rate         | 0.53        |
# | time/                   |             |
# |    fps                  | 273         |
# |    iterations           | 11          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.021746203 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.12       |
# |    explained_variance   | 0.657       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00377     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00915    |
# |    std                  | 0.866       |
# |    value_loss           | 0.0213      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -2.39      |
# |    success_rate         | 0.68       |
# | time/                   |            |
# |    fps                  | 268        |
# |    iterations           | 12         |
# |    time_elapsed         | 365        |
# |    total_timesteps      | 98304      |
# | train/                  |            |
# |    approx_kl            | 0.02417187 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.02      |
# |    explained_variance   | 0.634      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0311     |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.00809   |
# |    std                  | 0.847      |
# |    value_loss           | 0.0204     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -2.37       |
# |    success_rate         | 0.63        |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 13          |
# |    time_elapsed         | 398         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.023367906 |
# |    clip_fraction        | 0.274       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.91       |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00219    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00757    |
# |    std                  | 0.827       |
# |    value_loss           | 0.0192      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 50         |
# |    ep_rew_mean          | -2.3       |
# |    success_rate         | 0.71       |
# | time/                   |            |
# |    fps                  | 263        |
# |    iterations           | 14         |
# |    time_elapsed         | 435        |
# |    total_timesteps      | 114688     |
# | train/                  |            |
# |    approx_kl            | 0.02247844 |
# |    clip_fraction        | 0.285      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.84      |
# |    explained_variance   | 0.656      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0116    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00428   |
# |    std                  | 0.815      |
# |    value_loss           | 0.0177     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -2.16       |
# |    success_rate         | 0.73        |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 15          |
# |    time_elapsed         | 474         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.029381443 |
# |    clip_fraction        | 0.31        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.75       |
# |    explained_variance   | 0.69        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0674      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00736    |
# |    std                  | 0.796       |
# |    value_loss           | 0.017       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -2.07       |
# |    success_rate         | 0.74        |
# | time/                   |             |
# |    fps                  | 258         |
# |    iterations           | 16          |
# |    time_elapsed         | 506         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.023505963 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.67       |
# |    explained_variance   | 0.688       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00198    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00408    |
# |    std                  | 0.782       |
# |    value_loss           | 0.0159      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -1.91       |
# |    success_rate         | 0.89        |
# | time/                   |             |
# |    fps                  | 253         |
# |    iterations           | 17          |
# |    time_elapsed         | 549         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.030778427 |
# |    clip_fraction        | 0.311       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.58       |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00695     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 5.04e-05    |
# |    std                  | 0.766       |
# |    value_loss           | 0.0133      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -1.86       |
# |    success_rate         | 0.83        |
# | time/                   |             |
# |    fps                  | 249         |
# |    iterations           | 18          |
# |    time_elapsed         | 590         |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.022637112 |
# |    clip_fraction        | 0.297       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.49       |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00827    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.00302     |
# |    std                  | 0.748       |
# |    value_loss           | 0.0127      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -1.74       |
# |    success_rate         | 0.92        |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 19          |
# |    time_elapsed         | 622         |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.023529898 |
# |    clip_fraction        | 0.307       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.39       |
# |    explained_variance   | 0.684       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0386      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | 0.00357     |
# |    std                  | 0.733       |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -1.66       |
# |    success_rate         | 0.92        |
# | time/                   |             |
# |    fps                  | 248         |
# |    iterations           | 20          |
# |    time_elapsed         | 660         |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.032466993 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0519      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.00898     |
# |    std                  | 0.718       |
# |    value_loss           | 0.0102      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -1.69       |
# |    success_rate         | 0.85        |
# | time/                   |             |
# |    fps                  | 250         |
# |    iterations           | 21          |
# |    time_elapsed         | 687         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.038567595 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.695       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00765    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | 0.0105      |
# |    std                  | 0.699       |
# |    value_loss           | 0.00865     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 50        |
# |    ep_rew_mean          | -1.64     |
# |    success_rate         | 0.9       |
# | time/                   |           |
# |    fps                  | 254       |
# |    iterations           | 22        |
# |    time_elapsed         | 708       |
# |    total_timesteps      | 180224    |
# | train/                  |           |
# |    approx_kl            | 0.0399564 |
# |    clip_fraction        | 0.353     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.09     |
# |    explained_variance   | 0.659     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00719  |
# |    n_updates            | 210       |
# |    policy_gradient_loss | 0.00583   |
# |    std                  | 0.684     |
# |    value_loss           | 0.00781   |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -1.51       |
# |    success_rate         | 0.96        |
# | time/                   |             |
# |    fps                  | 259         |
# |    iterations           | 23          |
# |    time_elapsed         | 725         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.027138712 |
# |    clip_fraction        | 0.338       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0042     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | 0.00539     |
# |    std                  | 0.674       |
# |    value_loss           | 0.00685     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -1.47       |
# |    success_rate         | 0.98        |
# | time/                   |             |
# |    fps                  | 263         |
# |    iterations           | 24          |
# |    time_elapsed         | 746         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.028357562 |
# |    clip_fraction        | 0.33        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0401      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | 0.0101      |
# |    std                  | 0.653       |
# |    value_loss           | 0.00739     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50          |
# |    ep_rew_mean          | -1.43       |
# |    success_rate         | 0.99        |
# | time/                   |             |
# |    fps                  | 266         |
# |    iterations           | 25          |
# |    time_elapsed         | 767         |
# |    total_timesteps      | 204800      |
# | train/                  |             |
# |    approx_kl            | 0.039263234 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0275      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | 0.0132      |
# |    std                  | 0.642       |
# |    value_loss           | 0.00636     |
# -----------------------------------------
#  100% ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204,800/200,000  [ 0:12:39 < 0:00:00 , 324 it/s ]
# Training finished in 773.70 seconds.
# Final model saved to ppo_fetch_reach.zip
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
# --- Starting Evaluation ---
#   22% ━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221,184/1,000,000  [ 2:22:31 < -:--:-- , ? it/s ]
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:1698, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1697 with self:
# -> 1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    1701         end,
#    1702         justify=justify,
#    1703         emoji=emoji,
#    1704         markup=markup,
#    1705         highlight=highlight,
#    1706     )
#    1707     for hook in render_hooks:
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:1558, in Console._collect_renderables(self, objects, sep, end, justify, emoji, markup, highlight)
#    1556 if isinstance(renderable, str):
#    1557     append_text(
# -> 1558         self.render_str(
#    1559             renderable,
#    1560             emoji=emoji,
#    1561             markup=markup,
#    1562             highlight=highlight,
#    1563             highlighter=_highlighter,
#    1564         )
#    1565     )
#    1566 elif isinstance(renderable, Text):
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:1470, in Console.render_str(self, text, style, justify, overflow, emoji, markup, highlight, highlighter)
#    1469 if _highlighter is not None:
# -> 1470     highlight_text = _highlighter(str(rich_text))
#    1471     highlight_text.copy_styles(rich_text)
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\highlighter.py:38, in Highlighter.__call__(self, text)
#      37     raise TypeError(f"str or Text instance required, not {text!r}")
# ---> 38 self.highlight(highlight_text)
#      39 return highlight_text
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\highlighter.py:77, in RegexHighlighter.highlight(self, text)
#      76 for re_highlight in self.highlights:
# ---> 77     highlight_regex(re_highlight, style_prefix=self.base_style)
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\text.py:617, in Text.highlight_regex(self, re_highlight, style, style_prefix)
#     616 if isinstance(re_highlight, str):
# --> 617     re_highlight = re.compile(re_highlight)
#     618 for match in re_highlight.finditer(plain):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\re\__init__.py:228, in compile(pattern, flags)
#     227 "Compile a regular expression pattern, returning a Pattern object."
# --> 228 return _compile(pattern, flags)
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# Cell In[11], line 76
#      72 env.close()
#      74 # --- 7. Evaluate the Trained Agent ---
# ---> 76 print("\n--- Starting Evaluation ---")
#      78 # Load the trained model
#      79 model = PPO.load(MODEL_PATH)
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\IPython\core\interactiveshell.py:3045, in InteractiveShell._tee.<locals>.write(data, *args, **kwargs)
#    3043 def write(data, *args, **kwargs):
#    3044     """Write data to both the original destination and the capture dictionary."""
# -> 3045     result = original_write(data, *args, **kwargs)
#    3046     if any(
#    3047         [
#    3048             self.display_pub.is_publishing,
#    (...)   3051         ]
#    3052     ):
#    3053         return result
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\file_proxy.py:43, in FileProxy.write(self, text)
#      41 if lines:
#      42     console = self.__console
# ---> 43     with console:
#      44         output = Text("\n").join(
#      45             self.__ansi_decoder.decode_line(line) for line in lines
#      46         )
#      47         console.print(output)
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     868 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     869     """Exit buffer context."""
# --> 870     self._exit_buffer()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     824 """Leave buffer context, and render content if required."""
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2035     return
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#    2040     self.on_broken_pipe()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2051 if self.is_jupyter:  # pragma: no cover
#    2052     from .jupyter import display
# -> 2054     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055     del self._buffer[:]
#    2056 else:
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\ipykernel\zmqshell.py:149, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update, **kwargs)
#     145     if outputs is not None:
#     146         outputs.setdefault(exec_count, []).append(
#     147             HistoryOutput(output_type="display_data", bundle=data)
#     148         )
# --> 149 self._flush_streams()
#     150 if metadata is None:
#     151     metadata = {}
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\ipykernel\zmqshell.py:93, in ZMQDisplayPublisher._flush_streams(self)
#      91 def _flush_streams(self):
#      92     """flush IO Streams prior to display"""
# ---> 93     sys.stdout.flush()
#      94     sys.stderr.flush()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1695     crop = False
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#    1707     for hook in render_hooks:
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     868 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     869     """Exit buffer context."""
# --> 870     self._exit_buffer()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     824 """Leave buffer context, and render content if required."""
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2035     return
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#    2040     self.on_broken_pipe()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2051 if self.is_jupyter:  # pragma: no cover
#    2052     from .jupyter import display
# -> 2054     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055     del self._buffer[:]
#    2056 else:
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\ipykernel\zmqshell.py:149, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update, **kwargs)
#     145     if outputs is not None:
#     146         outputs.setdefault(exec_count, []).append(
#     147             HistoryOutput(output_type="display_data", bundle=data)
#     148         )
# --> 149 self._flush_streams()
#     150 if metadata is None:
#     151     metadata = {}
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\ipykernel\zmqshell.py:93, in ZMQDisplayPublisher._flush_streams(self)
#      91 def _flush_streams(self):
#      92     """flush IO Streams prior to display"""
# ---> 93     sys.stdout.flush()
#      94     sys.stderr.flush()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1695     crop = False
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#    1707     for hook in render_hooks:
#
#     [... skipping similar frames: Console.__exit__ at line 870 (268 times), Console._check_buffer at line 2038 (268 times), Console._exit_buffer at line 826 (268 times), Console._write_buffer at line 2054 (268 times), ZMQDisplayPublisher._flush_streams at line 93 (267 times), display at line 91 (267 times), display at line 285 (267 times), FileProxy.flush at line 53 (267 times), Console.print at line 1697 (267 times), ZMQDisplayPublisher.publish at line 149 (267 times), publish_display_data at line 73 (267 times)]
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\jupyter.py:91, in display(segments, text)
#      88 try:
#      89     from IPython.display import display as ipython_display
# ---> 91     ipython_display(jupyter_renderable)
#      92 except ModuleNotFoundError:
#      93     # Handle the case where the Console has force_jupyter=True,
#      94     # but IPython is not installed.
#      95     pass
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\IPython\core\display_functions.py:285, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     282         if metadata:
#     283             # kwarg-specified metadata gets precedence
#     284             _merge(md_dict, metadata)
# --> 285         publish_display_data(data=format_dict, metadata=md_dict, **kwargs)
#     286 if display_id:
#     287     return DisplayHandle(display_id)
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\IPython\core\display_functions.py:73, in publish_display_data(data, metadata, transient, **kwargs)
#      70 if transient:
#      71     kwargs['transient'] = transient
# ---> 73 display_pub.publish(
#      74     data=data,
#      75     metadata=metadata,
#      76     **kwargs
#      77 )
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\ipykernel\zmqshell.py:149, in ZMQDisplayPublisher.publish(self, data, metadata, transient, update, **kwargs)
#     145     if outputs is not None:
#     146         outputs.setdefault(exec_count, []).append(
#     147             HistoryOutput(output_type="display_data", bundle=data)
#     148         )
# --> 149 self._flush_streams()
#     150 if metadata is None:
#     151     metadata = {}
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\ipykernel\zmqshell.py:93, in ZMQDisplayPublisher._flush_streams(self)
#      91 def _flush_streams(self):
#      92     """flush IO Streams prior to display"""
# ---> 93     sys.stdout.flush()
#      94     sys.stderr.flush()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\file_proxy.py:53, in FileProxy.flush(self)
#      51 output = "".join(self.__buffer)
#      52 if output:
# ---> 53     self.__console.print(output)
#      54 del self.__buffer[:]
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:1697, in Console.print(self, sep, end, style, justify, overflow, no_wrap, emoji, markup, highlight, width, height, crop, soft_wrap, new_line_start, *objects)
#    1695     crop = False
#    1696 render_hooks = self._render_hooks[:]
# -> 1697 with self:
#    1698     renderables = self._collect_renderables(
#    1699         objects,
#    1700         sep,
#    (...)   1705         highlight=highlight,
#    1706     )
#    1707     for hook in render_hooks:
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:870, in Console.__exit__(self, exc_type, exc_value, traceback)
#     868 def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     869     """Exit buffer context."""
# --> 870     self._exit_buffer()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:826, in Console._exit_buffer(self)
#     824 """Leave buffer context, and render content if required."""
#     825 self._buffer_index -= 1
# --> 826 self._check_buffer()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:2038, in Console._check_buffer(self)
#    2035     return
#    2037 try:
# -> 2038     self._write_buffer()
#    2039 except BrokenPipeError:
#    2040     self.on_broken_pipe()
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\console.py:2054, in Console._write_buffer(self)
#    2051 if self.is_jupyter:  # pragma: no cover
#    2052     from .jupyter import display
# -> 2054     display(self._buffer, self._render_buffer(self._buffer[:]))
#    2055     del self._buffer[:]
#    2056 else:
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\jupyter.py:86, in display(segments, text)
#      84 def display(segments: Iterable[Segment], text: str) -> None:
#      85     """Render segments to Jupyter."""
# ---> 86     html = _render_segments(segments)
#      87     jupyter_renderable = JupyterRenderable(html, text)
#      88     try:
#
# File E:\SJSUStudy\CMPE260\.cmpe260\Lib\site-packages\rich\jupyter.py:67, in _render_segments(segments)
#      65 append_fragment = fragments.append
#      66 theme = DEFAULT_TERMINAL_THEME
# ---> 67 for text, style, control in Segment.simplify(segments):
#      68     if control:
#      69         continue
#
# RecursionError: maximum recursion depth exceeded

# %%
import time  # Add this import

print("\n--- Starting Evaluation ---")

# Load the trained model
model = PPO.load(MODEL_PATH)

# Create a single env for evaluation with "human" render mode
eval_env = gym.make(ENV_ID, render_mode="human")

# Optional: Load VecNormalize stats if used
# eval_env = VecNormalize.load("vec_normalize_fetch.pkl", eval_env)
# eval_env.training = False
# eval_env.norm_reward = False

N_EVAL_EPISODES = 10
for ep in range(N_EVAL_EPISODES):
    obs, info = eval_env.reset()
    done = False
    print(f"\nEvaluation Episode {ep + 1}")
    
    while not done:
        # Use deterministic=True for consistent evaluation
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, terminated, truncated, info = eval_env.step(action)

        # Pause a bit to slow down the loop
        done = terminated or truncated

        if done:
            print("Episode finished.")
            if info.get("is_success"):
                print(">>> Goal was reached! <<<")
            else:
                print(">>> Goal was NOT reached. <<<")
            
eval_env.close()
print("Evaluation complete.")
# Out:
# --- Starting Evaluation ---
#
# Evaluation Episode 1
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 2
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 3
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 4
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 5
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 6
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 7
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 8
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 9
# Episode finished.
# >>> Goal was reached! <<<
#
# Evaluation Episode 10
# Episode finished.
# >>> Goal was reached! <<<
# Evaluation complete.

# %%
env.action_space
# Out:
# Box(-1.0, 1.0, (4,), float32)
